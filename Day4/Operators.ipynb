# %% [markdown]
# Operators
#
# 1.arth( + - * / // ,modulus, exponenent(**)) ** means power or square.
#
# 2. com( < > <= >= == !=)
# 3.ass(= =+ -= /= *= //= %= **=)
# 4. logical(and or not )
# 5. membership(in  not in)
# 6. identity( is is not)
# 7. bitwise

# %%
a=20
b=10

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# 10

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 0

# %%
a**b
# Out:
# 10240000000000

# %%
4**5
# Out:
# 1024

# %%
9//5
# Out:
# 1

# %%
9/5
# Out:
# 1.8

# %%
17%4
# Out:
# 1

# %%
17%3
# Out:
# 2

# %%
17%4
# Out:
# 1

# %%
71%4
# Out:
# 3

# %%
17//4
# Out:
# 4

# %%
17/4
# Out:
# 4.25

# %%
71/4
# Out:
# 17.75

# %%
71//4
# Out:
# 17

# %% [markdown]
# comparision

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
10==10
# Out:
# True

# %%
26>29
# Out:
# False

# %%
y=5

# %%
y+5
# Out:
# 10

# %%
y-8
# Out:
# -3

# %%
y+10
# Out:
# 15

# %%
y
# Out:
# 5

# %%
y*5
# Out:
# 25

# %%
y//5
# Out:
# 1

# %%
y/5
# Out:
# 1.0

# %%
y+10
# Out:
# 15

# %%
y
# Out:
# 5

# %%
y=y+5

# %%
y
# Out:
# 10

# %%
y=y+10

# %%
y
# Out:
# 20

# %%
y=y+20

# %%
y
# Out:
# 40

# %%
y-20
# Out:
# 20

# %%
y+=10

# %%
y
# Out:
# 50

# %%
y
# Out:
# 50

# %%
y+=50

# %%
y
# Out:
# 100

# %%
y-=4

# %%
y
# Out:
# 96

# %%
a=20
b=10

# %%
a%10==0
# Out:
# True

# %%
a%20==0 and b%20==0 and a>b
# Out:
# False

# %%
a%20==0 or b%20==0 or a>b
# Out:
# True

# %%
5%3
# Out:
# 2

# %%
5%3==0
# Out:
# False

# %%
20%10==0
# Out:
# True

# %%
4%3==0 or 5%3==0
# Out:
# False

# %%
4%3==0 and 5%3==0
# Out:
# False

# %%
4%3==0 and 5%2==0
# Out:
# False

# %%
4%3==0 or 5%5==0
# Out:
# True

# %%
not a>b
# Out:
# False

# %%
not a<b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
not a>b
# Out:
# False

# %%
a='python programming'

# %%
'y' in a
# Out:
# True

# %%
'p' in a
# Out:
# True

# %%
'p'not in a
# Out:
# False

# %%
l=['python','java''c']

# %%
'python' in l
# Out:
# True

# %%
'mysql' in l
# Out:
# False

# %%
'python' not in l
# Out:
# False

# %%
t={1,2,3,4,44,5,56,6,7,77,87,54,34}

# %%
1 in t
# Out:
# True

# %%
2 in t
# Out:
# True

# %%
2 not in t
# Out:
# False

# %%
1 not in t
# Out:
# False

# %%
44 in t
# Out:
# True

# %%
44 not in t
# Out:
# False

# %%
100 in t
# Out:
# False

# %%
l=[1,2,3,4,5]
m=[1,2,3,4,5]

# %%
l==m
# Out:
# True

# %%
n=m

# %%
n
# Out:
# [1, 2, 3, 4, 5]

# %%
l is m
# Out:
# False

# %%
n is m
# Out:
# True

# %%
l is n
# Out:
# False

# %%
id(l)
# Out:
# 133110517946368

# %%
id(m)
# Out:
# 133110517673280

# %%
id(n)
# Out:
# 133110517673280

# %%
n==m
# Out:
# True

# %%
n==l
# Out:
# True

# %%
n is m
# Out:
# True

# %%
l is n
# Out:
# False

# %%
8&14
# Out:
# 8

# %%
8&7
# Out:
# 0

# %%
10^11
# Out:
# 1

# %%
8|7
# Out:
# 15

# %%
~8
# Out:
# -9

# %%
~11
# Out:
# -12

# %%
~3
# Out:
# -4

# %%
5>>2
# Out:
# 1

# %%
5<<2
# Out:
# 20

# %%
2<<4
# Out:
# 32

# %%
2>>4
# Out:
# 0

# %%
7>>2
# Out:
# 1

# %%
7<<2
# Out:
# 28

# %%
a=12

# %%
b=12.23

# %%
c='python'

# %%
print('a','b','c')
# Out:
# a b c

# %%
print(f'a ={a} b ={b} c={c}')
# Out:
# a =12 b =12.23 c=python

# %%
print('a={} b={} c={}'.format(a,b,c))
# Out:
# a=12 b=12.23 c=python

# %%
print('a={2} b={0} c={1}'.format(a,b,c))
# Out:
# a=python b=12 c=12.23
