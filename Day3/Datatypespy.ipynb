# %% [markdown]
# Numeric datatypes

# %%
a=10
type(a)
# Out:
# int

# %%
t=99.9
type(t)
# Out:
# float

# %%
a=12+9j
type(a)
# Out:
# complex

# %% [markdown]
# Sequence datatypes

# %%
a='pradeep'
type(a)
# Out:
# str

# %%
a="pradeep"
type(a)
# Out:
# str

# %%
a=[1,2,3]
type(a)
# Out:
# list

# %%
a=(1,2)
type(a)
# Out:
# tuple

# %%
a=(1,2,3,3,3,4)
a
# Out:
# (1, 2, 3, 3, 3, 4)

# %%
id(a)
# Out:
# 134429101656192

# %%
s='python'
id(s)
# Out:
# 134430101961680

# %%
l=[1,2,3,4]
l.append(50)
l.append(60)
l
# Out:
# [1, 2, 3, 4, 50, 60]

# %%
s={1,2,3,4}
type(s)
# Out:
# set

# %%
s=set()

# %%
s={4567,546,3456,13423}

# %%
s
# Out:
# {546, 3456, 4567, 13423}

# %%
d={'name':'abc','age':100,'course':'PFS'}
d
# Out:
# {'name': 'abc', 'age': 100, 'course': 'PFS'}

# %%
type(d)
# Out:
# dict

# %%
b=True
b=False
type(b)
# Out:
# bool

# %%
a=None
type(a)
# Out:
# NoneType

# %%
a=10
a
# Out:
# 10

# %%
float(a)
# Out:
# 10.0

# %%
complex(a)
# Out:
# (10+0j)

# %%
str(a)
# Out:
# '10'

# %%
list(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/943973770.py in <cell line: 0>()
# ----> 1 list(a)
#
# TypeError: 'int' object is not iterable

# %%
list[a]
# Out:
# list[10]

# %%
bool(a)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
b=10.5
int(b)
# Out:
# 10

# %%
complex(b)
# Out:
# (10.5+0j)

# %%
str(b)
# Out:
# '10.5'

# %%
bool(b)
# Out:
# True

# %%
c=2+3j
int(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/2344274644.py in <cell line: 0>()
#       1 c=2+3j
# ----> 2 int(c)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
str(c)
# Out:
# '(2+3j)'

# %%
bool(c)
# Out:
# True

# %%
s='python'
a='12244'
b='23.45'

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_26463/2179186071.py in <cell line: 0>()
# ----> 1 int(s)
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
int(a)
# Out:
# 12244

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_26463/3956108814.py in <cell line: 0>()
# ----> 1 int(b)
#
# ValueError: invalid literal for int() with base 10: '23.45'

# %%
float(b)
# Out:
# 23.45

# %%
float(a)
# Out:
# 12244.0

# %%
list(a)
# Out:
# ['1', '2', '2', '4', '4']

# %%
list(s)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
list(b)
# Out:
# ['2', '3', '.', '4', '5']

# %%
tuple(s)
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
set(s)
# Out:
# {'h', 'n', 'o', 'p', 't', 'y'}

# %%
complex(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_26463/3541782356.py in <cell line: 0>()
# ----> 1 complex(s)
#
# ValueError: complex() arg is a malformed string

# %%
complex(a)
# Out:
# (12244+0j)

# %%
complex(b)
# Out:
# (23.45+0j)

# %%
l=[1,2,3,4,5,6]
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
int(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/1414163800.py in <cell line: 0>()
# ----> 1 int(l)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
str(l)
# Out:
# '[1, 2, 3, 4, 5, 6]'

# %%
tuple(l)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
bool(l)
# Out:
# True

# %%
t=(1,2,2,2,3,4,5,6,7)
t
# Out:
# (1, 2, 2, 2, 3, 4, 5, 6, 7)

# %%
int(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/1000711840.py in <cell line: 0>()
# ----> 1 int(t)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'tuple'

# %%
str(t)
# Out:
# '(1, 2, 2, 2, 3, 4, 5, 6, 7)'

# %%
tuple(t)
# Out:
# (1, 2, 2, 2, 3, 4, 5, 6, 7)

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
bool(l)
# Out:
# True

# %%
s={1,1,2,3,4,5,5,6,8}

# %%
float(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/3205677745.py in <cell line: 0>()
# ----> 1 float(s)
#
# TypeError: float() argument must be a string or a real number, not 'set'

# %%
str(s)
# Out:
# '{1, 2, 3, 4, 5, 6, 8}'

# %%
tuple(s)
# Out:
# (1, 2, 3, 4, 5, 6, 8)

# %%
complex(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/3541782356.py in <cell line: 0>()
# ----> 1 complex(s)
#
# TypeError: complex() first argument must be a string or a number, not 'set'

# %%
dict(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/3728499651.py in <cell line: 0>()
# ----> 1 dict(s)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
bool(s)
# Out:
# True

# %%
d={1:2,2:3,3:4,4:5}
d
# Out:
# {1: 2, 2: 3, 3: 4, 4: 5}

# %%
int(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/2949999978.py in <cell line: 0>()
# ----> 1 int(d)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'dict'

# %%
str(d)
# Out:
# '{1: 2, 2: 3, 3: 4, 4: 5}'

# %%
tuple(d)
# Out:
# (1, 2, 3, 4)

# %%
list(d)
# Out:
# [1, 2, 3, 4]

# %%
bool(d)
# Out:
# True

# %%
s=True

# %%
int(s)
# Out:
# 1

# %%
float(s)
# Out:
# 1.0

# %%
str(s)
# Out:
# 'True'

# %%
complex(s)
# Out:
# (1+0j)

# %%
tuple(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26463/3964775515.py in <cell line: 0>()
# ----> 1 tuple(s)
#
# TypeError: 'bool' object is not iterable
