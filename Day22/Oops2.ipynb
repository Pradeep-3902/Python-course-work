# %%
class Hotstar:
  def __init__(self,name):
    self.name=name
    print(f'Hi {self.name},Welcome to the hotstar')
  def login(self):
    print('You can login')
  def dashboard(self):
    print('You can see the dashboard items')
  def search(self):
    print('You can search')
  def languages(self):
    print('You can select the languages')
  def playcontrollers(self):
    print('You can pause and play the video')
  def ads(self):
    print('Ads will run')
  def movies(self):
    print('You can limited access for movies')
  def sports(self):
    print('Limited time you can watch sports')
  def quality(self):
    print('Limited quality')

pradeep=Hotstar('pradeep')
pradeep.login()
pradeep.dashboard()
pradeep.search()
pradeep.languages()
pradeep.playcontrollers()
pradeep.ads()
pradeep.movies()
pradeep.sports()
pradeep.quality()
# Out:
# Hi pradeep,Welcome to the hotstar
# You can login
# You can see the dashboard items
# You can search
# You can select the languages
# You can pause and play the video
# Ads will run
# You can limited access for movies
# Limited time you can watch sports
# Limited quality

# %%
class premiumHotstar(Hotstar):
  def __init__(self,name):
    self.name=name
    print(f'Hi {self.name}, Welcome to the premium Hotstar')
  def ads(self):
    print("Ads won't run")
  def movies(self):
    print('you have unlimted access for movies')
  def sports(self):
    print('you can watch sports')
  def quality(self):
    print('High quality')
Tanish=premiumHotstar('Tanish')
Tanish.login()
Tanish.dashboard()
Tanish.search()
Tanish.languages()
Tanish.playcontrollers()
Tanish.ads()
Tanish.movies()
Tanish.sports()
Tanish.quality()
# Out:
# Hi Tanish, Welcome to the premium Hotstar
# You can login
# You can see the dashboard items
# You can search
# You can select the languages
# You can pause and play the video
# Ads won't run
# you have unlimted access for movies
# you can watch sports
# High quality

# %%
class Number:
  def __init__(self,n):
    self.n=n
  def __add__(self,other):
    return self.n+other.n
  def __sub__(self,other):
    return self.n-other.n
  def __mul__(self,other):
    return self.n*other.n
  def __truediv__(self,other):
    return self.n/other.n
  def __eq__(self,other):
    return self.n==other.n
  def __lt__(self,other):
    return self.n<other.n
  def __gt__(self,other):
    return self.n>other.n
  def __str__(self):
    return str(self.n)
n1=Number(10)
n2=Number(20)

print(n1+n2)
print(n1-n2)
print(n1*n2)
print(n1/n2)
print(n1==n2)
print(n1<n2)
print(n1>n2)
print(n1,n2)
# Out:
# 30
# -10
# 200
# 0.5
# False
# True
# False
# 10 20
