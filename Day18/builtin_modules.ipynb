# %%
import sys
print(sys.argv)
print(sys.path)
print(sys.version)

print("Before exit")
# sys.exit()
print("After exit")
# Out:
# ['/usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-d578fac7-a60d-47ca-b015-4ce204a45749.json']
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython']
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Before exit
# After exit

# %%
import platform
print(platform.system(),platform.release(),platform.processor())
# Out:
# Linux 6.6.122+ x86_64

# %%
import math
print(math.pi)
print(math.e)

print(math.sqrt(25))
print(math.pow(2,5))

print(math.ceil(12.3))
print(math.ceil(12.000001))
print(math.ceil(12.9999999))
print(math.ceil(12.8))

print(math.floor(12.3))
print(math.floor(12.000001))
print(math.floor(12.9999999))
print(math.floor(12.8))

print(math.factorial(5))
# Out:
# 3.141592653589793
# 2.718281828459045
# 5.0
# 32.0
# 13
# 13
# 13
# 13
# 12
# 12
# 12
# 12
# 120

# %%
import math
print(math.fabs(-12))
print(math.factorial(5))
print(math.gcd(8,28))

print(math.log(10,10))
print(math.sin(10))
print(math.cos(10))
print(math.tan(10))

print(math.degrees(20))
print(math.radians(20))
# Out:
# 12.0
# 120
# 4
# 1.0
# -0.5440211108893698
# -0.8390715290764524
# 0.6483608274590866
# 1145.9155902616465
# 0.3490658503988659

# %%
import random
print(random.random())
print(random.randint(1,6))
print(random.randrange(1,6))
l=['python','c','c++','java','html']
print(random.choice(l))
print(random.choices(l,k=3))

s='rps'
print(random.choice(s))
print(l)
random.shuffle(l)
print(l)
# Out:
# 0.3771838384333933
# 5
# 5
# c
# ['c++', 'java', 'c']
# r
# ['python', 'c', 'c++', 'java', 'html']
# ['c', 'html', 'java', 'c++', 'python']

# %%
import collections
s='python programming language'
d={}
for i in s:
  if i in d:
    d[i]+=1
  else:
    d[i]=1
print(d)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 3, ' ': 2, 'r': 2, 'g': 4, 'a': 3, 'm': 2, 'i': 1, 'l': 1, 'u': 1, 'e': 1}

# %%
import collections
s='python programming language'
d=collections.defaultdict(int)
for i in s:
    d[i]+=1
print(d)
# Out:
# defaultdict(<class 'int'>, {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 3, ' ': 2, 'r': 2, 'g': 4, 'a': 3, 'm': 2, 'i': 1, 'l': 1, 'u': 1, 'e': 1})

# %%
import collections
l=collections.deque([])
l.appendleft(10)
l.appendleft(20)
l.appendleft(30)
l.appendleft(40)
l.pop()
l.pop()
l.pop()
l.appendleft(50)
l.appendleft(60)
l.pop()
# Out:
# 40

# %%
import itertools
print(list(itertools.combinations('abcd',2)))
print(list(itertools.permutations('abcd',2)))
# Out:
# [('a', 'b'), ('a', 'c'), ('a', 'd'), ('b', 'c'), ('b', 'd'), ('c', 'd')]
# [('a', 'b'), ('a', 'c'), ('a', 'd'), ('b', 'a'), ('b', 'c'), ('b', 'd'), ('c', 'a'), ('c', 'b'), ('c', 'd'), ('d', 'a'), ('d', 'b'), ('d', 'c')]

# %%
from itertools import combinations,permutations
com=combinations('abcd',2)
print([''.join(i) for i in com])

per=permutations('abcd',2)
print([''.join(i) for i in per])
# Out:
# ['ab', 'ac', 'ad', 'bc', 'bd', 'cd']
# ['ab', 'ac', 'ad', 'ba', 'bc', 'bd', 'ca', 'cb', 'cd', 'da', 'db', 'dc']
