# %%
d={}

# %%
d=dict()

# %%
type(d)
# Out:
# dict

# %%
d={'k1':'v1',':k2':'v2'}

# %%
d
# Out:
# {'k1': 'v1', ':k2': 'v2'}

# %%
d={}

# %%
d[1]='int'

# %%
d
# Out:
# {1: 'int'}

# %%
d[12.3]='float'

# %%
d
# Out:
# {1: 'int', 12.3: 'float'}

# %%
d['demo']='str'

# %%
d
# Out:
# {1: 'int', 12.3: 'float', 'demo': 'str'}

# %%
d[2+3j]='complex'

# %%
d
# Out:
# {1: 'int', 12.3: 'float', 'demo': 'str', (2+3j): 'complex'}

# %%
d[False]='bool'

# %%
d
# Out:
# {1: 'int', 12.3: 'float', 'demo': 'str', (2+3j): 'complex', False: 'bool'}

# %%
d={}

# %%
d[1]=1

# %%
d
# Out:
# {1: 1}

# %%
d[23]=23.4

# %%
d[3]='fdghjk'

# %%
d[4]=3+4j

# %%
d[5]=[1,2,3]

# %%
d[6]=(1,2,3)

# %%
d[7]={1,3}

# %%
d[8]={1:1,2:2}

# %%
d[9]=False

# %%
d
# Out:
# {1: 1,
#  23: 23.4,
#  3: 'fdghjk',
#  4: (3+4j),
#  5: [1, 2, 3],
#  6: (1, 2, 3),
#  7: {1, 3},
#  8: {1: 1, 2: 2},
#  9: False}

# %%
d={}

# %%
d[1]=14

# %%
d
# Out:
# {1: 14}

# %%
d={}

# %%
d[1]=2

# %%
d[2]=2

# %%
d[3]=2

# %%
d[4]=2

# %%
d
# Out:
# {1: 2, 2: 2, 3: 2, 4: 2}

# %%
d[3]
# Out:
# 2

# %%
d={1:2,2:4,3:6,4:8,5:10,6:12}

# %%
d[4]
# Out:
# 8

# %%
d[6]
# Out:
# 12

# %%
d[1]
# Out:
# 2

# %%
d[4]
# Out:
# 8

# %%
d={'somu':90,'jassu':76,'vamsi':78,'srav':80}

# %%
d['jassu']
# Out:
# 76

# %%
d['srav']
# Out:
# 80

# %%
d.get('sai')

# %%
d.get('somu')
# Out:
# 90

# %%
d.get('mani','user not found')
# Out:
# 'user not found'

# %%
d.get('jassu','user not found')
# Out:
# 76

# %%
'jassu' in d
# Out:
# True

# %%
'vamsi' in d
# Out:
# True

# %%
'sai' not in d
# Out:
# True

# %%
d.keys()
# Out:
# dict_keys(['somu', 'jassu', 'vamsi', 'srav'])

# %%
d.values()
# Out:
# dict_values([90, 76, 78, 80])

# %%
d.items()
# Out:
# dict_items([('somu', 90), ('jassu', 76), ('vamsi', 78), ('srav', 80)])

# %%
sorted(d)
# Out:
# ['jassu', 'somu', 'srav', 'vamsi']

# %%
d
# Out:
# {'somu': 90, 'jassu': 76, 'vamsi': 78, 'srav': 80}

# %%
min(d)
# Out:
# 'jassu'

# %%
max(d)
# Out:
# 'vamsi'

# %%
len(d)
# Out:
# 4

# %%
d
# Out:
# {'somu': 90, 'jassu': 76, 'vamsi': 78, 'srav': 80}

# %%
d['rohith']=83

# %%
d
# Out:
# {'somu': 90, 'jassu': 76, 'vamsi': 78, 'srav': 80, 'rohith': 83}

# %%
d['jassu']=75

# %%
d
# Out:
# {'somu': 90, 'jassu': 75, 'vamsi': 78, 'srav': 80, 'rohith': 83}

# %%
d.update({'aravind':89,'siva':95})

# %%
d
# Out:
# {'somu': 90,
#  'jassu': 75,
#  'vamsi': 78,
#  'srav': 80,
#  'rohith': 83,
#  'aravind': 89,
#  'siva': 95}

# %%
d.popitem()
# Out:
# ('siva', 95)

# %%
d
# Out:
# {'somu': 90, 'jassu': 75, 'vamsi': 78, 'srav': 80, 'rohith': 83, 'aravind': 89}

# %%
d.pop('somu')
# Out:
# 90

# %%
d
# Out:
# {'jassu': 75, 'vamsi': 78, 'srav': 80, 'rohith': 83, 'aravind': 89}

# %%
del d['vamsi']

# %%
d
# Out:
# {'jassu': 75, 'srav': 80, 'rohith': 83, 'aravind': 89}

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
d.setdefault('jassu',0)
# Out:
# 0

# %%
d
# Out:
# {'jassu': 0}

# %%
s='python programming'

# %%
if 'python' in s:
  print('python found')
# Out:
# python found

# %%
if s[0]=='p':
  print('string is starting with p')
# Out:
# string is starting with p

# %%
data=('abc','1234')
username,password=input("Enter the username and password").split()
if data==(username,password):
  print('login successfull')
else:
  print('invalid login')
# Out:
# Enter the username and passwordabc 1234
# login successfull

# %%
n=int(input("Enter the num:"))
if n>0:
  print('positive')
elif n<0:
  print('negative')
else:
  print('Zero')
# Out:
# Enter the num:2
# positive

# %%
products={'laptop':0,'mouse':10,'charger':5,'phones':30,'keyboard':0}
product=input("Enter the product: ")
if product in products:
  if products[product]!=0:
    print('product available')
  else:
    print('product out of stock')
else:
  print('product not found')
# Out:
# Enter the product: mouse
# product available
