# %%
t=(1,2,3,4,5)

# %%
t
# Out:
# (1, 2, 3, 4, 5)

# %%
t=()

# %%
t=(1,1,1,1,1)

# %%
t
# Out:
# (1, 1, 1, 1, 1)

# %%
t=(1,1.1,'tryu',[])
t
# Out:
# (1, 1.1, 'tryu', [])

# %%
t=(10,20,30,40,50)

# %%
t
# Out:
# (10, 20, 30, 40, 50)

# %%
h=(90,80,70)

# %%
h
# Out:
# (90, 80, 70)

# %%
t+h
# Out:
# (10, 20, 30, 40, 50, 90, 80, 70)

# %%
t*4
# Out:
# (10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  20,
#  30,
#  40,
#  50)

# %%
t
# Out:
# (10, 20, 30, 40, 50)

# %%
t[1]
# Out:
# 20

# %%
t[3]
# Out:
# 40

# %%
t[4]
# Out:
# 50

# %%
t[2]
# Out:
# 30

# %%
t
# Out:
# (10, 20, 30, 40, 50)

# %%
t[:3]
# Out:
# (10, 20, 30)

# %%
t[3:]
# Out:
# (40, 50)

# %%
t[1:4]
# Out:
# (20, 30, 40)

# %%
t[2:]
# Out:
# (30, 40, 50)

# %%
t[::2]
# Out:
# (10, 30, 50)

# %%
t[-1:-4:-1]
# Out:
# (50, 40, 30)

# %%
t
# Out:
# (10, 20, 30, 40, 50)

# %%
10 in t
# Out:
# True

# %%
30 in t
# Out:
# True

# %%
60 not in t
# Out:
# True

# %%
10 not in t
# Out:
# False

# %%
25 in t
# Out:
# False

# %%
t
# Out:
# (10, 20, 30, 40, 50)

# %%
len(t)
# Out:
# 5

# %%
sorted(t)
# Out:
# [10, 20, 30, 40, 50]

# %%
min(t)
# Out:
# 10

# %%
max(t)
# Out:
# 50

# %%
sum(t)
# Out:
# 150

# %%
t.count(10)
# Out:
# 1

# %%
t.index(10)
# Out:
# 0

# %%
t=(1,2,3,4,5,6,7)

# %%
t
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
t[2]
# Out:
# 3

# %%
a=(1,2,4)

# %%
a
# Out:
# (1, 2, 4)

# %%
x,y,z=a

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
z
# Out:
# 4

# %%
t=(1,2,3,[4,5,6],7,8)
t
# Out:
# (1, 2, 3, [4, 5, 6], 7, 8)

# %%
t[2]
# Out:
# 3

# %%
t[4]
# Out:
# 7

# %%
t[3]
# Out:
# [4, 5, 6]

# %%
t[2]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3200/244757425.py in <cell line: 0>()
# ----> 1 t[2]=4
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[3]
# Out:
# [4, 5, 6]

# %%
t[3].append(10)

# %%
t
# Out:
# (1, 2, 3, [4, 5, 6, 10], 7, 8)

# %% [markdown]
# Sets

# %%
s={1,2,3,4}

# %%
a
# Out:
# (1, 2, 4)

# %%
s=set()

# %%
s
# Out:
# set()

# %%
s={1,2,1,1,1,1,1,}
s
# Out:
# {1, 2}

# %%
s={76,12,879,53435,3190}

# %%
s
# Out:
# {12, 76, 879, 3190, 53435}

# %%
s.add(1)

# %%
s
# Out:
# {1, 12, 76, 879, 3190, 53435}

# %%
s.add(1)

# %%
s.add(56.567)

# %%
s
# Out:
# {1, 12, 56.567, 76, 879, 3190, 53435}

# %%
s.add('kjhy')

# %%
s
# Out:
# {1, 12, 3190, 53435, 56.567, 76, 879, 'kjhy'}

# %%
s
# Out:
# {1, 12, 3190, 53435, 56.567, 76, 879, 'kjhy'}

# %%
1 in s
# Out:
# True

# %%
2 in s
# Out:
# False

# %%
False not in s
# Out:
# True

# %%
a=1,2,3,5,6,8,10

# %%
b={6,7,8,9}

# %%
a | b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3200/201546576.py in <cell line: 0>()
# ----> 1 a | b
#
# TypeError: unsupported operand type(s) for |: 'tuple' and 'set'

# %%
set(a) | b
# Out:
# {1, 2, 3, 5, 6, 7, 8, 9, 10}

# %%
a.intersection(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3200/4123925746.py in <cell line: 0>()
# ----> 1 a.intersection(b)
#
# AttributeError: 'tuple' object has no attribute 'intersection'

# %%
set(a)&b
# Out:
# {6, 8}

# %%
set(a)-b
# Out:
# {1, 2, 3, 5, 10}

# %%
set(a)^b
# Out:
# {1, 2, 3, 5, 7, 9, 10}

# %%
a
# Out:
# (1, 2, 3, 5, 6, 8, 10)

# %%
print(set(a)<={1})
# Out:
# False

# %%
set(a)>={1}
# Out:
# True

# %%
a
# Out:
# (1, 2, 3, 5, 6, 8, 10)

# %%
a = a + (14,)
print(a)
# Out:
# (1, 2, 3, 5, 6, 8, 10, 14)

# %%
a = a[:-1]
print(a)
# Out:
# (1, 2, 3, 5, 6, 8, 10)

# %%
a.discard(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3200/1626664172.py in <cell line: 0>()
# ----> 1 a.discard(6)
#
# AttributeError: 'tuple' object has no attribute 'discard'

# %%
len(a)
# Out:
# 7
